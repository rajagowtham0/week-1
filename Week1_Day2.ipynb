# %%
# loading the dataset and printing the head
import pandas as pd
df = pd.read_csv(r"C:\Users\rajak\Downloads\skin_cancer_prediction_clinical_data.csv")
df.head(10)
# Out:
#   Patient_ID  Age  Gender Skin_Type UV_Exposure_Level  Family_History  \
# 0  PID100000   69    Male         V               Low               0
# 1  PID100001   32    Male        IV              High               0
# 2  PID100002   89    Male         I          Moderate               0
# 3  PID100003   78    Male         I              High               1
# 4  PID100004   38  Female         V               Low               1
# 5  PID100005   41  Female        IV          Moderate               1
# 6  PID100006   20  Female        IV               Low               1
# 7  PID100007   39  Female        II               Low               0
# 8  PID100008   70    Male        VI               Low               0
# 9  PID100009   19    Male       III              High               1
#
#    History_of_Sunburns  Mole_Count  Itching  Bleeding  ...  Evolving  Pain  \
# 0                    1          13        0         1  ...         0     0
# 1                    4          11        0         0  ...         0     0
# 2                    3          15        0         0  ...         0     0
# 3                    4           9        0         0  ...         0     0
# 4                    2          12        0         0  ...         0     0
# 5                    0          20        0         0  ...         0     0
# 6                    0          17        0         0  ...         0     0
# 7                    3          15        0         0  ...         0     0
# 8                    4          11        1         0  ...         0     0
# 9                    2          16        0         0  ...         0     0
#
#    Scaliness  Oozing  Location  Immune_Status   Smoking_Habit  \
# 0          0       0     Chest         Normal      Non-Smoker
# 1          0       0      Face     Suppressed      Non-Smoker
# 2          0       0      Face         Normal  Current Smoker
# 3          0       0     Scalp         Normal      Non-Smoker
# 4          0       0      Back     Suppressed  Current Smoker
# 5          1       0      Legs     Suppressed      Non-Smoker
# 6          0       0      Legs     Suppressed      Non-Smoker
# 7          0       0      Arms         Normal   Former Smoker
# 8          0       0      Face         Normal      Non-Smoker
# 9          1       1     Chest         Normal      Non-Smoker
#
#    Alcohol_Consumption    BMI Cancer_Diagnosis
# 0                 High  27.24                0
# 1             Moderate  28.32                0
# 2             Moderate  25.69                0
# 3             Moderate  27.44                0
# 4             Moderate  33.46                0
# 5             Moderate  23.24                0
# 6                  NaN  23.45                0
# 7             Moderate  33.42                0
# 8                  NaN  30.20                0
# 9             Moderate  24.31                0
#
# [10 rows x 24 columns]

# %%
df.head(10)
# Out:
#   Patient_ID  Age  Gender Skin_Type UV_Exposure_Level  Family_History  \
# 0  PID100000   69    Male         V               Low               0
# 1  PID100001   32    Male        IV              High               0
# 2  PID100002   89    Male         I          Moderate               0
# 3  PID100003   78    Male         I              High               1
# 4  PID100004   38  Female         V               Low               1
# 5  PID100005   41  Female        IV          Moderate               1
# 6  PID100006   20  Female        IV               Low               1
# 7  PID100007   39  Female        II               Low               0
# 8  PID100008   70    Male        VI               Low               0
# 9  PID100009   19    Male       III              High               1
#
#    History_of_Sunburns  Mole_Count  Itching  Bleeding  ...  Evolving  Pain  \
# 0                    1          13        0         1  ...         0     0
# 1                    4          11        0         0  ...         0     0
# 2                    3          15        0         0  ...         0     0
# 3                    4           9        0         0  ...         0     0
# 4                    2          12        0         0  ...         0     0
# 5                    0          20        0         0  ...         0     0
# 6                    0          17        0         0  ...         0     0
# 7                    3          15        0         0  ...         0     0
# 8                    4          11        1         0  ...         0     0
# 9                    2          16        0         0  ...         0     0
#
#    Scaliness  Oozing  Location  Immune_Status   Smoking_Habit  \
# 0          0       0     Chest         Normal      Non-Smoker
# 1          0       0      Face     Suppressed      Non-Smoker
# 2          0       0      Face         Normal  Current Smoker
# 3          0       0     Scalp         Normal      Non-Smoker
# 4          0       0      Back     Suppressed  Current Smoker
# 5          1       0      Legs     Suppressed      Non-Smoker
# 6          0       0      Legs     Suppressed      Non-Smoker
# 7          0       0      Arms         Normal   Former Smoker
# 8          0       0      Face         Normal      Non-Smoker
# 9          1       1     Chest         Normal      Non-Smoker
#
#    Alcohol_Consumption    BMI Cancer_Diagnosis
# 0                 High  27.24                0
# 1             Moderate  28.32                0
# 2             Moderate  25.69                0
# 3             Moderate  27.44                0
# 4             Moderate  33.46                0
# 5             Moderate  23.24                0
# 6                  NaN  23.45                0
# 7             Moderate  33.42                0
# 8                  NaN  30.20                0
# 9             Moderate  24.31                0
#
# [10 rows x 24 columns]

# %%
# importing the libraries
import pandas as pd
# loading the dataset
df = pd.read_csv(r"C:\Users\rajak\Downloads\skin_cancer_prediction_clinical_data.csv")
# printing the shape of the dataset
print("Dataset Shape (Rows, Columns):")
print(df.shape)
# printing the columns that exist in the dataset
print("\nColumn Names:")
for col in df.columns:
    print(col)
# printing the type of each column
print("\nData Types of Each Column:")
print(df.dtypes)
# Out:
# Dataset Shape (Rows, Columns):
# (3000, 24)
#
# Column Names:
# Patient_ID
# Age
# Gender
# Skin_Type
# UV_Exposure_Level
# Family_History
# History_of_Sunburns
# Mole_Count
# Itching
# Bleeding
# Asymmetry
# Border_Irregularity
# Color_Variation
# Diameter_mm
# Evolving
# Pain
# Scaliness
# Oozing
# Location
# Immune_Status
# Smoking_Habit
# Alcohol_Consumption
# BMI
# Cancer_Diagnosis
#
# Data Types of Each Column:
# Patient_ID              object
# Age                      int64
# Gender                  object
# Skin_Type               object
# UV_Exposure_Level       object
# Family_History           int64
# History_of_Sunburns      int64
# Mole_Count               int64
# Itching                  int64
# Bleeding                 int64
# Asymmetry                int64
# Border_Irregularity      int64
# Color_Variation          int64
# Diameter_mm            float64
# Evolving                 int64
# Pain                     int64
# Scaliness                int64
# Oozing                   int64
# Location                object
# Immune_Status           object
# Smoking_Habit           object
# Alcohol_Consumption     object
# BMI                    float64
# Cancer_Diagnosis         int64
# dtype: object

# %%
# Display concise summary of the dataset
print("\nDataset Information:")
df.info()
# Statistical summary of numerical features
print("\nStatistical Description of Numerical Features:")
df.describe()
# Out:
# Dataset Information:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3000 entries, 0 to 2999
# Data columns (total 24 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Patient_ID           3000 non-null   object
#  1   Age                  3000 non-null   int64
#  2   Gender               3000 non-null   object
#  3   Skin_Type            3000 non-null   object
#  4   UV_Exposure_Level    3000 non-null   object
#  5   Family_History       3000 non-null   int64
#  6   History_of_Sunburns  3000 non-null   int64
#  7   Mole_Count           3000 non-null   int64
#  8   Itching              3000 non-null   int64
#  9   Bleeding             3000 non-null   int64
#  10  Asymmetry            3000 non-null   int64
#  11  Border_Irregularity  3000 non-null   int64
#  12  Color_Variation      3000 non-null   int64
#  13  Diameter_mm          3000 non-null   float64
#  14  Evolving             3000 non-null   int64
#  15  Pain                 3000 non-null   int64
#  16  Scaliness            3000 non-null   int64
#  17  Oozing               3000 non-null   int64
#  18  Location             3000 non-null   object
#  19  Immune_Status        3000 non-null   object
#  20  Smoking_Habit        3000 non-null   object
#  21  Alcohol_Consumption  1525 non-null   object
#  22  BMI                  3000 non-null   float64
#  23  Cancer_Diagnosis     3000 non-null   int64
# dtypes: float64(2), int64(14), object(8)
# memory usage: 562.6+ KB
#
# Statistical Description of Numerical Features:
#                Age  Family_History  History_of_Sunburns   Mole_Count  \
# count  3000.000000      3000.00000          3000.000000  3000.000000
# mean     52.891000         0.31000             2.043000    14.981333
# std      20.684448         0.46257             1.444477     3.924553
# min      18.000000         0.00000             0.000000     3.000000
# 25%      35.000000         0.00000             1.000000    12.000000
# 50%      52.000000         0.00000             2.000000    15.000000
# 75%      71.000000         1.00000             3.000000    18.000000
# max      89.000000         1.00000             8.000000    32.000000
#
#            Itching     Bleeding    Asymmetry  Border_Irregularity  \
# count  3000.000000  3000.000000  3000.000000          3000.000000
# mean      0.150000     0.094000     0.197000             0.202333
# std       0.357131     0.291877     0.397799             0.401806
# min       0.000000     0.000000     0.000000             0.000000
# 25%       0.000000     0.000000     0.000000             0.000000
# 50%       0.000000     0.000000     0.000000             0.000000
# 75%       0.000000     0.000000     0.000000             0.000000
# max       1.000000     1.000000     1.000000             1.000000
#
#        Color_Variation  Diameter_mm     Evolving         Pain    Scaliness  \
# count      3000.000000  3000.000000  3000.000000  3000.000000  3000.000000
# mean          0.256000     4.991430     0.145667     0.097667     0.206000
# std           0.436495     1.960332     0.352831     0.296913     0.404498
# min           0.000000    -0.970000     0.000000     0.000000     0.000000
# 25%           0.000000     3.627500     0.000000     0.000000     0.000000
# 50%           0.000000     4.960000     0.000000     0.000000     0.000000
# 75%           1.000000     6.312500     0.000000     0.000000     0.000000
# max           1.000000    11.670000     1.000000     1.000000     1.000000
#
#             Oozing          BMI  Cancer_Diagnosis
# count  3000.000000  3000.000000       3000.000000
# mean      0.048000    24.855293          0.144000
# std       0.213802     4.062748          0.351148
# min       0.000000    10.870000          0.000000
# 25%       0.000000    22.185000          0.000000
# 50%       0.000000    24.940000          0.000000
# 75%       0.000000    27.512500          0.000000
# max       1.000000    38.780000          1.000000

# %%
# categorising the features into their specific groups
# Numerical features
numerical_features = [
    "Mole_Count", "Diameter_mm", "BMI"
]
# Binary clinical indicators
binary_features = [
    "Family_History", "History_of_Sunburns",
    "Itching", "Bleeding", "Asymmetry",
    "Border_Irregularity", "Color_Variation",
    "Evolving", "Pain", "Scaliness", "Oozing",
    "Cancer_Diagnosis"
]
# Categorical features
categorical_features = [
    "Skin_Type", "UV_Exposure_Level",
    "Location", "Immune_Status",
    "Smoking_Habit", "Alcohol_Consumption"
]
print("Numerical Features:", numerical_features)
print("\nBinary Features:", binary_features)
print("\nCategorical Features:", categorical_features)
# Out:
# Numerical Features: ['Mole_Count', 'Diameter_mm', 'BMI']
#
# Binary Features: ['Family_History', 'History_of_Sunburns', 'Itching', 'Bleeding', 'Asymmetry', 'Border_Irregularity', 'Color_Variation', 'Evolving', 'Pain', 'Scaliness', 'Oozing', 'Cancer_Diagnosis']
#
# Categorical Features: ['Skin_Type', 'UV_Exposure_Level', 'Location', 'Immune_Status', 'Smoking_Habit', 'Alcohol_Consumption']

# %%
# grouping the severity features
severity_features = [
    "Itching",
    "Bleeding",
    "Asymmetry",
    "Border_Irregularity",
    "Color_Variation",
    "Evolving",
    "Pain",
    "Scaliness",
    "Oozing"
]
# Compute Severity Indicator Score
df["Severity_Indicator_Score"] = np.sum(
    df[severity_features].values, axis=1
)
#printing the results
print(df[["Patient_ID", "Severity_Indicator_Score"]].head())
#statistics of the severity score
print("\nSeverity Indicator Statistics:")
print(df["Severity_Indicator_Score"].describe())
# Out:
#   Patient_ID  Severity_Indicator_Score
# 0  PID100000                         1
# 1  PID100001                         1
# 2  PID100002                         1
# 3  PID100003                         0
# 4  PID100004                         0
#
# Severity Indicator Statistics:
# count    3000.000000
# mean        1.396667
# std         1.077826
# min         0.000000
# 25%         1.000000
# 50%         1.000000
# 75%         2.000000
# max         6.000000
# Name: Severity_Indicator_Score, dtype: float64

# %%
#finding the nearest patient
# Selecting features for similarity
similarity_features = [
    "Mole_Count",
    "Diameter_mm",
    "BMI",
    "Severity_Indicator_Score"
]

X = df[similarity_features].values
patient_ids = df["Patient_ID"].values

num_patients = X.shape[0]
distance_matrix = np.zeros((num_patients, num_patients))

for i in range(num_patients):
    for j in range(num_patients):
        distance_matrix[i, j] = norm(X[i] - X[j])

nearest_list = []

for i, pid in enumerate(patient_ids):
    distances = distance_matrix[i].copy()
    distances[i] = np.inf
    nearest_index = np.argmin(distances)
    nearest_list.append([pid, patient_ids[nearest_index]])

nearest_df = pd.DataFrame(
    nearest_list,
    columns=["Patient_ID", "Nearest_Patient"]
)

print("\nNearest patient for each individual:")
print(nearest_df)
# Out:
# Nearest patient for each individual:
#      Patient_ID Nearest_Patient
# 0     PID100000       PID100753
# 1     PID100001       PID102008
# 2     PID100002       PID100171
# 3     PID100003       PID102952
# 4     PID100004       PID100427
# ...         ...             ...
# 2995  PID102995       PID101960
# 2996  PID102996       PID102875
# 2997  PID102997       PID100349
# 2998  PID102998       PID101622
# 2999  PID102999       PID101972
#
# [3000 rows x 2 columns]

# %%
# K-means-based clustering of the patients
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans
# feature standardaisation
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)
# K-Means clustering into three groups
kmeans = KMeans(n_clusters=3, random_state=42)
df["Risk_Cluster"] = kmeans.fit_predict(X_scaled)
# View cluster-wise mean characteristics
cluster_summary = df.groupby("Risk_Cluster")[similarity_features].mean()
print(cluster_summary)
# Out:
#               Mole_Count  Diameter_mm        BMI  Severity_Indicator_Score
# Risk_Cluster
# 0              17.296468     6.382026  25.567305                  0.940520
# 1              13.416058     3.487089  25.237774                  0.895985
# 2              14.044686     5.175580  23.423744                  2.652174

# %%
# Severity score distribution across risk groups
df.groupby("Risk_Cluster")["Severity_Indicator_Score"].describe()
# Out:
#                count      mean       std  min  25%  50%  75%  max
# Risk_Cluster
# 0             1076.0  0.940520  0.760779  0.0  0.0  1.0  1.0  3.0
# 1             1096.0  0.895985  0.698428  0.0  0.0  1.0  1.0  3.0
# 2              828.0  2.652174  0.795868  1.0  2.0  3.0  3.0  6.0

# %%
# Mean lesion diameter per 
df.groupby("Risk_Cluster")["Diameter_mm"].mean()
# Out:
# Risk_Cluster
# 0    6.382026
# 1    3.487089
# 2    5.175580
# Name: Diameter_mm, dtype: float64

# %%
# patient history analysis
df.groupby("Risk_Cluster")[
    ["Mole_Count", "History_of_Sunburns"]
].mean()
# Out:
#               Mole_Count  History_of_Sunburns
# Risk_Cluster
# 0              17.296468             2.065056
# 1              13.416058             2.018248
# 2              14.044686             2.047101
